# %%
import pandas as pd

# %%
imm_df = pd.read_csv('immigration_population_d1.csv', error_bad_lines=False)
# Out:
# <ipython-input-113-5e3fec3852a3>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   imm_df = pd.read_csv('immigration_population_d1.csv', error_bad_lines=False)

# %%
imm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130092 entries, 0 to 130091
# Data columns (total 20 columns):
#  #   Column                                           Non-Null Count   Dtype
# ---  ------                                           --------------   -----
#  0   REF_DATE                                         130092 non-null  int64
#  1   GEO                                              130092 non-null  object
#  2   DGUID                                            130092 non-null  object
#  3   Citizenship (9)                                  130092 non-null  object
#  4   Age (8D)                                         130092 non-null  object
#  5   Gender (3)                                       130092 non-null  object
#  6   Statistics (3)                                   130092 non-null  object
#  7   Place of birth (290)                             130092 non-null  object
#  8   Immigrant status and period of immigration (11)  130092 non-null  object
# ...

# %% [markdown]
# One row was not read because of a formatting issue. Add that row manually after processing.

# %%
imm_df.tail(5)
# Out:
#         REF_DATE      GEO        DGUID        Citizenship (9)     Age (8D)  \
# 130087      2021  Nunavut  2021A000262  Not Canadian citizens  Total - Age
# 130088      2021  Nunavut  2021A000262  Not Canadian citizens  Total - Age
# 130089      2021  Nunavut  2021A000262  Not Canadian citizens  Total - Age
# 130090      2021  Nunavut  2021A000262  Not Canadian citizens  Total - Age
# 130091      2021  Nunavut  2021A000262  Not Canadian citizens  Total - Age
#
#        Gender (3) Statistics (3) Place of birth (290)  \
# 130087     Women+          Count                India
# 130088     Women+          Count             Pakistan
# 130089     Women+          Count             Pakistan
# 130090     Women+          Count             Pakistan
# 130091     Women+          Count             Pakistan
#
#           Immigrant status and period of immigration (11)  UOM  UOM_ID  \
# 130087                                       2016 to 2021  NaN       0
# ...

# %%
imm_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Citizenship (9)', 'Age (8D)', 'Gender (3)',
#        'Statistics (3)', 'Place of birth (290)',
#        'Immigrant status and period of immigration (11)', 'UOM', 'UOM_ID',
#        'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS',
#        'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
filtered_df = imm_df[['GEO', 'Gender (3)', 'Immigrant status and period of immigration (11)','Place of birth (290)', 'VALUE' ]]

# %%
filtered_df.head()
# Out:
#       GEO      Gender (3)    Immigrant status and period of immigration (11)  \
# 0  Canada  Total - Gender  Total - Immigrant status and period of immigra...
# 1  Canada  Total - Gender                                         Immigrants
# 2  Canada  Total - Gender  Total - Immigrant status and period of immigra...
# 3  Canada  Total - Gender                                         Immigrants
# 4  Canada  Total - Gender                                       2011 to 2021
#
#         Place of birth (290)  VALUE
# 0                  Greenland     30
# 1                  Greenland     25
# 2  Saint Pierre and Miquelon    510
# 3  Saint Pierre and Miquelon    355
# 4  Saint Pierre and Miquelon     30

# %% [markdown]
# Remove values from Place of birth with Total – Place of birth and Gender (3)	with Total - Gender

# %%
filtered_df = filtered_df[filtered_df['Place of birth (290)'] != 'Total – Place of birth']

# %%
filtered_df = filtered_df[filtered_df['Gender (3)'] != 'Total - Gender']

# %%
#finding unique values in column: Immigrant status and period of immigration (11)

filtered_df['Immigrant status and period of immigration (11)'].unique()
# Out:
# array(['Total - Immigrant status and period of immigration', 'Immigrants',
#        '2011 to 2021', '2016 to 2021'], dtype=object)

# %%
#filter the rows that are only within the year range of 2016 - 2021
filtered_df = filtered_df[filtered_df['Immigrant status and period of immigration (11)'] == '2016 to 2021']

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16078 entries, 818 to 130091
# Data columns (total 5 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   GEO                                              16078 non-null  object
#  1   Gender (3)                                       16078 non-null  object
#  2   Immigrant status and period of immigration (11)  16078 non-null  object
#  3   Place of birth (290)                             16078 non-null  object
#  4   VALUE                                            16078 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 753.7+ KB

# %%
#finding unique values in column: Place of birth (290)

filtered_df['Place of birth (290)'].unique()

# %%
#finding unique values in column: GEO

filtered_df['GEO'].unique()
# Out:
# array(['Canada', 'Newfoundland and Labrador', "St. John's (CMA), N.L.",
#        'Prince Edward Island', 'Nova Scotia', 'Halifax (CMA), N.S.',
#        'New Brunswick', 'Fredericton (CMA), N.B.', 'Moncton (CMA), N.B.',
#        'Saint John (CMA), N.B.', 'Quebec', 'Drummondville (CMA), Que.',
#        'Montréal (CMA), Que.', 'Québec (CMA), Que.',
#        'Saguenay (CMA), Que.', 'Sherbrooke (CMA), Que.',
#        'Trois-Rivières (CMA), Que.', 'Ontario', 'Barrie (CMA), Ont.',
#        'Belleville - Quinte West (CMA), Ont.', 'Brantford (CMA), Ont.',
#        'Greater Sudbury (CMA), Ont.', 'Guelph (CMA), Ont.',
#        'Hamilton (CMA), Ont.', 'Kingston (CMA), Ont.',
#        'Kitchener - Cambridge - Waterloo (CMA), Ont.',
#        'London (CMA), Ont.', 'Oshawa (CMA), Ont.',
#        'Ottawa - Gatineau (CMA), Ont./Que.',
#        'Ottawa - Gatineau (Ontario part) (CMA), Ont.',
#        'Ottawa - Gatineau (Quebec part) (CMA), Que.',
# ...

# %%
#remove rows with 'GEO' in the column 

filtered_df = filtered_df[filtered_df['GEO'] != 'Canada']

# %%
filtered_df.head()
# Out:
#                             GEO Gender (3)  \
# 5162  Newfoundland and Labrador       Men+
# 5170  Newfoundland and Labrador       Men+
# 5184  Newfoundland and Labrador       Men+
# 5188  Newfoundland and Labrador       Men+
# 5194  Newfoundland and Labrador       Men+
#
#      Immigrant status and period of immigration (11)  \
# 5162                                    2016 to 2021
# 5170                                    2016 to 2021
# 5184                                    2016 to 2021
# 5188                                    2016 to 2021
# 5194                                    2016 to 2021
#
#           Place of birth (290)  VALUE
# 5162  United States of America     75
# 5170                    Mexico     15
# 5184                   Jamaica     65
# 5188       Trinidad and Tobago     15
# 5194                    Brazil     10

# %%
continent_to_countries = {
    'North America': [
        'United States of America', 'Mexico', 'Jamaica', 'Trinidad and Tobago',
        'Bahamas', 'Canada', 'Antigua and Barbuda', 'Barbados', 'Bermuda',
        'Cayman Islands', 'Cuba', 'Dominican Republic', 'Saint Vincent and the Grenadines',
        'Guatemala', 'Saint Lucia', 'Honduras', 'Haiti', 'Costa Rica',
        'El Salvador', 'Nicaragua', 'Panama', 'Grenada', 'Guadeloupe',
        'Martinique', 'Puerto Rico', 'Turks and Caicos Islands', 'Belize',
        'Dominica', 'Sint Maarten (Dutch part)', 'Virgin Islands, British',
        'Virgin Islands, United States', 'Aruba', 'Curaçao',
        'Saint Martin (French part)', 'Saint Kitts and Nevis'
    ],
    'South America': [
        'Brazil', 'Colombia', 'Peru', 'Chile', 'Argentina', 'Venezuela',
        'Ecuador', 'Guyana', 'Bolivia', 'Uruguay', 'Paraguay',
        'Suriname', 'French Guiana'
    ],
    'Europe': [
        'Belgium', 'France', 'Germany', 'Russian Federation', 'Denmark',
        'Ireland', 'United Kingdom', 'Italy', 'Switzerland', 'Romania',
        'Ukraine', 'Netherlands', 'Bulgaria', 'Albania', 'Kosovo',
        'Iceland', 'Croatia', 'Serbia', 'Spain', 'Hungary', 'Sweden',
        'North Macedonia', 'Austria', 'Lithuania', 'Moldova', 'Norway',
        'Luxembourg', 'Monaco', 'Czechia', 'Latvia', 'Slovakia', 'Finland',
        'Bosnia and Herzegovina', 'Greece', 'Montenegro', 'Portugal',
        'Estonia', 'Isle of Man', 'Jersey', 'Malta', 'Andorra', 'Slovenia', 'Belarus', 'Poland'
    ],
    'Asia': [
        'Iran', 'Iraq', 'Jordan', 'Kazakhstan', 'Lebanon', 'Saudi Arabia',
        'Syria', 'Turkey', 'United Arab Emirates', 'China', 'Philippines',
        'Thailand', 'Viet Nam', 'Bangladesh', 'India', 'Pakistan',
        'Sri Lanka', 'Kuwait', 'Yemen', 'Korea, South', 'Taiwan',
        'Israel', 'Hong Kong', 'Myanmar', 'Nepal', 'West Bank and Gaza Strip',
        'Japan', 'Indonesia', 'Laos', 'Armenia', 'Azerbaijan', 'Cyprus',
        'Tajikistan', 'Turkmenistan', 'Uzbekistan', 'Mongolia', 'Cambodia',
        'Singapore', 'Bhutan', 'Georgia', 'Brunei Darussalam', 'Macao', 'Afghanistan', 
        'Bahrain', 'Oman', 'Qatar', 'Malaysia', 'Kyrgyzstan', 'Korea, North'
    ],
    'Africa': [
        'Ghana', 'Nigeria', 'Eritrea', 'South Sudan', 'Zimbabwe', 'Egypt',
        'Libya', 'Sudan', 'Tunisia', 'Central African Republic',
        'Congo, Democratic Republic of the', 'South Africa, Republic of',
        'Ethiopia', 'Mauritius', 'Tanzania', 'Cameroon', 'Morocco',
        'Kenya', "Côte d'Ivoire", 'Liberia', 'Benin', 'Guinea', 'Mali',
        'Niger', 'Senegal', 'Togo', 'Madagascar', 'Chad', 'Gabon',
        'Burkina Faso', 'Gambia', 'Guinea-Bissau', 'Mauritania', 'Comoros',
        'Djibouti', 'Malawi', 'Mozambique', 'Réunion', 'Angola',
        'Congo, Republic of the', 'Botswana', 'Eswatini', 'Lesotho',
        'Seychelles', 'Burundi', 'Rwanda', 'Somalia', 'Uganda', 'Zambia', 'Algeria', 'Namibia', 'Sierra Leone' ],
    
    'Australia': [
        'Australia', 'Fiji', 'Kiribati', 'Marshall Islands', 'Micronesia, Federated States of',
        'Nauru', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa',
        'Solomon Islands', 'Tonga', 'Tuvalu', 'Vanuatu'
    ]
}

# %%
country_to_continent_combined = {}
for continent, countries in continent_to_countries.items():
    for country in countries:
        country_to_continent_combined[country] = continent

# Add a new column 'continent' to the DataFrame
filtered_df['Continent'] = filtered_df['Place of birth (290)'].map(country_to_continent_combined)

# %%
filtered_df[filtered_df['Continent'] == 'Asia']
# Out:
#                               GEO Gender (3)  \
# 5365    Newfoundland and Labrador       Men+
# 5369    Newfoundland and Labrador       Men+
# 5375    Newfoundland and Labrador       Men+
# 5379    Newfoundland and Labrador       Men+
# 5386    Newfoundland and Labrador       Men+
# ...                           ...        ...
# 130046                    Nunavut       Men+
# 130078                    Nunavut     Women+
# 130083                    Nunavut     Women+
# 130087                    Nunavut     Women+
# 130091                    Nunavut     Women+
#
#        Immigrant status and period of immigration (11) Place of birth (290)  \
# 5365                                      2016 to 2021                 Iran
# 5369                                      2016 to 2021                 Iraq
# 5375                                      2016 to 2021               Jordan
# 5379                                      2016 to 2021           Kazakhstan
# ...

# %%
filtered_df = filtered_df.rename(columns={'Place of birth (290)': 'Country'})

# %%
filtered_df = filtered_df.rename(columns={'GEO': 'Canadian Province/CMA'})

# %%
filtered_df = filtered_df.rename(columns={'VALUE': 'Population'})

# %%
filtered_df = filtered_df.rename(columns={'Gender (3)': 'Gender'})

# %%
missing_continent_rows = filtered_df[filtered_df['Continent'].isnull()]

# %%
missing_continent_rows['Country'].unique()
# Out:
# array([], dtype=object)

# %%
cleaned_df = filtered_df[['Canadian Province/CMA', 'Country', 'Continent','Gender','Population']]

# %%
cleaned_df.head()
# Out:
#           Canadian Province/CMA                   Country      Continent  \
# 5162  Newfoundland and Labrador  United States of America  North America
# 5170  Newfoundland and Labrador                    Mexico  North America
# 5184  Newfoundland and Labrador                   Jamaica  North America
# 5188  Newfoundland and Labrador       Trinidad and Tobago  North America
# 5194  Newfoundland and Labrador                    Brazil  South America
#
#      Gender  Population
# 5162   Men+          75
# 5170   Men+          15
# 5184   Men+          65
# 5188   Men+          15
# 5194   Men+          10

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15313 entries, 5162 to 130091
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Canadian Province/CMA  15313 non-null  object
#  1   Country                15313 non-null  object
#  2   Continent              15313 non-null  object
#  3   Gender                 15313 non-null  object
#  4   Population             15313 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 717.8+ KB

# %%
cleaned_df.to_csv('immigration_statistics_d1.csv', index=False)
