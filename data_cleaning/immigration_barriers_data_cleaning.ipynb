# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('../raw_datasets/immigration_discrimination_d4.csv')
df1.head()
# Out:
#    REF_DATE     GEO           DGUID                  Visible minority  \
# 0      2020  Canada  2021A000011124  Total, by visible minority group
# 1      2020  Canada  2021A000011124  Total, by visible minority group
# 2      2020  Canada  2021A000011124  Total, by visible minority group
# 3      2020  Canada  2021A000011124  Total, by visible minority group
# 4      2020  Canada  2021A000011124  Total, by visible minority group
#
#   Selected sociodemographic characteristics  \
# 0                                Immigrants
# 1                                Immigrants
# 2                                Immigrants
# 3                                Immigrants
# 4                                Immigrants
#
#                                           Indicators             Statistics  \
# 0  Experience(s) of discrimination, 5 years befor...  Percentage of persons
# 1  Experience(s) of discrimination based on ethni...  Percentage of persons
# ...

# %%
final_df1 = df1[['GEO','Visible minority', 'Selected sociodemographic characteristics', 'Indicators', 'VALUE']]
final_df1.head()
# Out:
#       GEO                  Visible minority  \
# 0  Canada  Total, by visible minority group
# 1  Canada  Total, by visible minority group
# 2  Canada  Total, by visible minority group
# 3  Canada  Total, by visible minority group
# 4  Canada  Total, by visible minority group
#
#   Selected sociodemographic characteristics  \
# 0                                Immigrants
# 1                                Immigrants
# 2                                Immigrants
# 3                                Immigrants
# 4                                Immigrants
#
#                                           Indicators  VALUE
# 0  Experience(s) of discrimination, 5 years befor...   40.7
# 1  Experience(s) of discrimination based on ethni...   22.1
# 2  Experience(s) of discrimination based on race ...   23.6
# 3  Experience(s) of discrimination based on langu...   15.8
# 4  Discrimination at work or when applying for a ...   45.6

# %%
final_df1.shape
# Out:
# (100, 5)

# %%
final_df1.isnull().sum()
# Out:
# GEO                                          0
# Visible minority                             0
# Selected sociodemographic characteristics    0
# Indicators                                   0
# VALUE                                        3
# dtype: int64

# %%
final_df1.duplicated().any()
# Out:
# False

# %%
final_df1.to_csv('../cleaned_datasets/immigrant_discrimination_cleaned_data_d4.csv', index=False)

# %%
df2 = pd.read_csv('../raw_datasets/immigrants_sense_of_belonging_d4.csv')
df2.head()
# Out:
#    REF_DATE     GEO           DGUID                  Visible minority  \
# 0      2020  Canada  2021A000011124  Total, by visible minority group
# 1      2020  Canada  2021A000011124  Total, by visible minority group
# 2      2020  Canada  2021A000011124  Total, by visible minority group
# 3      2020  Canada  2021A000011124  Total, by visible minority group
# 4      2020  Canada  2021A000011124  Total, by visible minority group
#
#   Selected sociodemographic characteristics  \
# 0                                Immigrants
# 1                                Immigrants
# 2                                Immigrants
# 3                                Immigrants
# 4                                Immigrants
#
#                                           Indicators             Statistics  \
# 0  Reported that most people can be trusted in ge...  Percentage of persons
# 1   Strong sense of belonging to the local community  Percentage of persons
# ...

# %%
final_df2 = df2[['GEO','Visible minority', 'Selected sociodemographic characteristics', 'Indicators', 'VALUE']]
final_df2.head()
# Out:
#       GEO                  Visible minority  \
# 0  Canada  Total, by visible minority group
# 1  Canada  Total, by visible minority group
# 2  Canada  Total, by visible minority group
# 3  Canada  Total, by visible minority group
# 4  Canada  Total, by visible minority group
#
#   Selected sociodemographic characteristics  \
# 0                                Immigrants
# 1                                Immigrants
# 2                                Immigrants
# 3                                Immigrants
# 4                                Immigrants
#
#                                           Indicators  VALUE
# 0  Reported that most people can be trusted in ge...   57.2
# 1   Strong sense of belonging to the local community   77.2
# 2      Strong sense of belonging to the town or city   81.3
# 3          Strong sense of belonging to the province   81.1
# 4                Strong sense of belonging to Canada   87.8

# %%
final_df2.shape
# Out:
# (50, 5)

# %%
final_df2.isnull().sum()
# Out:
# GEO                                          0
# Visible minority                             0
# Selected sociodemographic characteristics    0
# Indicators                                   0
# VALUE                                        0
# dtype: int64

# %%
final_df2.duplicated().any()
# Out:
# False

# %%
final_df2.to_csv('../cleaned_datasets/immigrant_sense_of_belonging_cleaned_data_d4.csv')

# %%
df3 = pd.read_csv('../raw_datasets/immigrants_feeling_part_of_community_d4.csv')
df3.head()
# Out:
#    REF_DATE     GEO           DGUID          Visible minority  \
# 0      2021  Canada  2016A000011124  Total – Visible minority
# 1      2021  Canada  2016A000011124  Total – Visible minority
# 2      2021  Canada  2016A000011124  Total – Visible minority
# 3      2021  Canada  2016A000011124  Total – Visible minority
# 4      2021  Canada  2016A000011124  Total – Visible minority
#
#   Selected sociodemographic characteristics  \
# 0                                Immigrants
# 1                                Immigrants
# 2                                Immigrants
# 3                                Immigrants
# 4                                Immigrants
#
#                                           Indicators             Statistics  \
# 0       Satisfied with feeling part of the community  Percentage of persons
# 1                   Satisfied with the neighbourhood  Percentage of persons
# 2  Feeling safe walking in their area alone after...  Percentage of persons
# ...

# %%
final_df3 = df3[['GEO', 'Visible minority', 'Selected sociodemographic characteristics', 'Indicators', 'VALUE']]
final_df3.head()
# Out:
#       GEO          Visible minority Selected sociodemographic characteristics  \
# 0  Canada  Total – Visible minority                                Immigrants
# 1  Canada  Total – Visible minority                                Immigrants
# 2  Canada  Total – Visible minority                                Immigrants
# 3  Canada  Total – Visible minority                                Immigrants
# 4  Canada  Total – Visible minority                                Immigrants
#
#                                           Indicators  VALUE
# 0       Satisfied with feeling part of the community   46.0
# 1                   Satisfied with the neighbourhood   67.0
# 2  Feeling safe walking in their area alone after...   78.0
# 3  Feeling unsafe walking in their area alone aft...   14.9
# 4    Difficulty in meeting household financial needs   29.0

# %%
final_df3.shape
# Out:
# (60, 5)

# %%
final_df3.isnull().sum()
# Out:
# GEO                                          0
# Visible minority                             0
# Selected sociodemographic characteristics    0
# Indicators                                   0
# VALUE                                        0
# dtype: int64

# %%
final_df3.duplicated().any()
# Out:
# False

# %%
final_df3.to_csv('../cleaned_datasets/immigrant_feeling_part_of_community_cleaned_data_d4.csv')

# %%
df4 = pd.read_csv('../raw_datasets/immigrants_size_of_network_d4.csv')
df4.head()
# Out:
#    REF_DATE     GEO           DGUID                  Visible minority  \
# 0      2020  Canada  2021A000011124  Total, by visible minority group
# 1      2020  Canada  2021A000011124  Total, by visible minority group
# 2      2020  Canada  2021A000011124  Total, by visible minority group
# 3      2020  Canada  2021A000011124  Total, by visible minority group
# 4      2020  Canada  2021A000011124  Total, by visible minority group
#
#   Selected sociodemographic characteristics  \
# 0                                Immigrants
# 1                                Immigrants
# 2                                Immigrants
# 3                                Immigrants
# 4                                Immigrants
#
#                                           Indicators             Statistics  \
# 0  Having no one in the local personal network (c...  Percentage of persons
# 1  Having 1 to 14 people in the local personal ne...  Percentage of persons
# ...

# %%
final_df4 = df4[['GEO','Visible minority', 'Selected sociodemographic characteristics', 'Indicators', 'VALUE']]
final_df4.head()
# Out:
#       GEO                  Visible minority  \
# 0  Canada  Total, by visible minority group
# 1  Canada  Total, by visible minority group
# 2  Canada  Total, by visible minority group
# 3  Canada  Total, by visible minority group
# 4  Canada  Total, by visible minority group
#
#   Selected sociodemographic characteristics  \
# 0                                Immigrants
# 1                                Immigrants
# 2                                Immigrants
# 3                                Immigrants
# 4                                Immigrants
#
#                                           Indicators  VALUE
# 0  Having no one in the local personal network (c...    3.8
# 1  Having 1 to 14 people in the local personal ne...   53.0
# 2  Having 15 or more people in the local personal...   43.2
# 3             Feeling close to 4 relatives or less     60.2
# 4             Feeling close to 5 relatives or more     39.8

# %%
final_df4.shape
# Out:
# (110, 5)

# %%
final_df4.isnull().sum()
# Out:
# GEO                                          0
# Visible minority                             0
# Selected sociodemographic characteristics    0
# Indicators                                   0
# VALUE                                        0
# dtype: int64

# %%
final_df4.duplicated().any()
# Out:
# False

# %%
final_df4.to_csv('../cleaned_datasets/immigrant_size_of_network_cleaned_data_d4.csv')

# %%
df5 = pd.read_csv('../raw_datasets/immigrants_loneliness_d4.csv')
df5.head()
# Out:
#   REF_DATE                             GEO           DGUID  \
# 0  2022-01  Canada (excluding territories)  2016A000011124
# 1  2022-04  Canada (excluding territories)  2016A000011124
# 2  2022-07  Canada (excluding territories)  2016A000011124
# 3  2022-10  Canada (excluding territories)  2016A000011124
# 4  2022-01  Canada (excluding territories)  2016A000011124
#
#                Gender Sociodemographic characteristics  \
# 0  Total, all persons                       Immigrants
# 1  Total, all persons                       Immigrants
# 2  Total, all persons                       Immigrants
# 3  Total, all persons                       Immigrants
# 4  Total, all persons                       Immigrants
#
#                      Indicators             Statistics      UOM  UOM_ID  \
# 0  Always or often feels lonely  Percentage of persons  Percent     239
# 1  Always or often feels lonely  Percentage of persons  Percent     239
# ...

# %%
final_df5 = df5[['GEO','Gender', 'Sociodemographic characteristics', 'Indicators', 'VALUE']]
final_df5.head()
# Out:
#                               GEO              Gender  \
# 0  Canada (excluding territories)  Total, all persons
# 1  Canada (excluding territories)  Total, all persons
# 2  Canada (excluding territories)  Total, all persons
# 3  Canada (excluding territories)  Total, all persons
# 4  Canada (excluding territories)  Total, all persons
#
#   Sociodemographic characteristics                    Indicators  VALUE
# 0                       Immigrants  Always or often feels lonely   12.1
# 1                       Immigrants  Always or often feels lonely   12.8
# 2                       Immigrants  Always or often feels lonely   12.0
# 3                       Immigrants  Always or often feels lonely   14.3
# 4                       Immigrants        Sometimes feels lonely   36.9

# %%
final_df5.shape
# Out:
# (108, 5)

# %%
final_df5.isnull().sum()
# Out:
# GEO                                 0
# Gender                              0
# Sociodemographic characteristics    0
# Indicators                          0
# VALUE                               0
# dtype: int64

# %%
final_df5.duplicated().any()
# Out:
# True

# %%
final_df5.to_csv('../cleaned_datasets/immigrant_loneliness_cleaned_data_d4.csv')
